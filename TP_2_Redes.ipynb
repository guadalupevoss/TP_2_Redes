#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg001.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg005.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg006.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg007.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg021.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg049.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg059.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg067.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg072.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg075.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg092.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg096.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg100.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg102.tif
#   inflating: PhC-C2DH-U373/01_GT/SEG/man_seg112.tif
#    creating: PhC-C2DH-U373/01_GT/TRA/
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track.txt
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track000.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track001.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track002.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track003.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track004.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track005.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track006.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track007.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track008.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track009.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track010.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track011.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track012.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track013.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track014.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track015.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track016.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track017.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track018.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track019.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track020.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track021.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track022.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track023.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track024.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track025.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track026.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track027.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track028.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track029.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track030.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track031.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track032.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track033.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track034.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track035.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track036.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track037.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track038.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track039.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track040.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track041.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track042.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track043.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track044.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track045.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track046.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track047.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track048.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track049.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track050.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track051.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track052.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track053.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track054.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track055.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track056.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track057.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track058.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track059.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track060.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track061.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track062.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track063.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track064.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track065.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track066.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track067.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track068.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track069.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track070.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track071.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track072.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track073.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track074.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track075.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track076.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track077.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track078.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track079.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track080.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track081.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track082.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track083.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track084.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track085.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track086.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track087.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track088.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track089.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track090.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track091.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track092.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track093.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track094.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track095.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track096.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track097.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track098.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track099.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track100.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track101.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track102.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track103.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track104.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track105.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track106.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track107.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track108.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track109.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track110.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track111.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track112.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track113.tif
#   inflating: PhC-C2DH-U373/01_GT/TRA/man_track114.tif
#    creating: PhC-C2DH-U373/01_ST/
#    creating: PhC-C2DH-U373/01_ST/SEG/
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg000.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg001.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg002.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg003.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg004.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg005.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg006.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg007.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg008.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg009.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg010.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg011.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg012.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg013.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg014.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg015.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg016.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg017.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg018.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg019.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg020.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg021.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg022.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg023.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg024.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg025.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg026.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg027.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg028.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg029.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg030.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg031.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg032.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg033.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg034.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg035.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg036.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg037.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg038.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg039.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg040.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg041.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg042.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg043.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg044.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg045.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg046.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg047.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg048.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg049.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg050.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg051.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg052.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg053.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg054.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg055.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg056.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg057.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg058.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg059.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg060.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg061.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg062.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg063.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg064.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg065.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg066.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg067.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg068.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg069.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg070.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg071.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg072.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg073.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg074.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg075.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg076.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg077.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg078.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg079.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg080.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg081.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg082.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg083.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg084.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg085.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg086.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg087.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg088.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg089.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg090.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg091.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg092.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg093.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg094.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg095.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg096.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg097.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg098.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg099.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg100.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg101.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg102.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg103.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg104.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg105.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg106.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg107.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg108.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg109.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg110.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg111.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg112.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg113.tif
#   inflating: PhC-C2DH-U373/01_ST/SEG/man_seg114.tif
#    creating: PhC-C2DH-U373/02/
#   inflating: PhC-C2DH-U373/02/t000.tif
#   inflating: PhC-C2DH-U373/02/t001.tif
#   inflating: PhC-C2DH-U373/02/t002.tif
#   inflating: PhC-C2DH-U373/02/t003.tif
#   inflating: PhC-C2DH-U373/02/t004.tif
#   inflating: PhC-C2DH-U373/02/t005.tif
#   inflating: PhC-C2DH-U373/02/t006.tif
#   inflating: PhC-C2DH-U373/02/t007.tif
#   inflating: PhC-C2DH-U373/02/t008.tif
#   inflating: PhC-C2DH-U373/02/t009.tif
#   inflating: PhC-C2DH-U373/02/t010.tif
#   inflating: PhC-C2DH-U373/02/t011.tif
#   inflating: PhC-C2DH-U373/02/t012.tif
#   inflating: PhC-C2DH-U373/02/t013.tif
#   inflating: PhC-C2DH-U373/02/t014.tif
#   inflating: PhC-C2DH-U373/02/t015.tif
#   inflating: PhC-C2DH-U373/02/t077.tif
#   inflating: PhC-C2DH-U373/02/t078.tif
#   inflating: PhC-C2DH-U373/02/t079.tif
#   inflating: PhC-C2DH-U373/02/t080.tif
#   inflating: PhC-C2DH-U373/02/t081.tif
#   inflating: PhC-C2DH-U373/02/t082.tif
#   inflating: PhC-C2DH-U373/02/t083.tif
#   inflating: PhC-C2DH-U373/02/t084.tif
#   inflating: PhC-C2DH-U373/02/t085.tif
#   inflating: PhC-C2DH-U373/02/t086.tif
#   inflating: PhC-C2DH-U373/02/t087.tif
#   inflating: PhC-C2DH-U373/02/t088.tif
#   inflating: PhC-C2DH-U373/02/t089.tif
#   inflating: PhC-C2DH-U373/02/t090.tif
#   inflating: PhC-C2DH-U373/02/t091.tif
#   inflating: PhC-C2DH-U373/02/t092.tif
#   inflating: PhC-C2DH-U373/02/t093.tif
#   inflating: PhC-C2DH-U373/02/t094.tif
#   inflating: PhC-C2DH-U373/02/t095.tif
#   inflating: PhC-C2DH-U373/02/t096.tif
#   inflating: PhC-C2DH-U373/02/t097.tif
#   inflating: PhC-C2DH-U373/02/t098.tif
#   inflating: PhC-C2DH-U373/02/t099.tif
#   inflating: PhC-C2DH-U373/02/t100.tif
#   inflating: PhC-C2DH-U373/02/t101.tif
#   inflating: PhC-C2DH-U373/02/t102.tif
#   inflating: PhC-C2DH-U373/02/t103.tif
#   inflating: PhC-C2DH-U373/02/t104.tif
#   inflating: PhC-C2DH-U373/02/t105.tif
#   inflating: PhC-C2DH-U373/02/t106.tif
#   inflating: PhC-C2DH-U373/02/t107.tif
#   inflating: PhC-C2DH-U373/02/t108.tif
#   inflating: PhC-C2DH-U373/02/t109.tif
#   inflating: PhC-C2DH-U373/02/t110.tif
#   inflating: PhC-C2DH-U373/02/t111.tif
#   inflating: PhC-C2DH-U373/02/t112.tif
#   inflating: PhC-C2DH-U373/02/t113.tif
#   inflating: PhC-C2DH-U373/02/t114.tif
#    creating: PhC-C2DH-U373/02_GT/
#    creating: PhC-C2DH-U373/02_GT/SEG/
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg010.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg017.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg019.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg020.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg022.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg026.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg035.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg036.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg041.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg049.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg051.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg052.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg059.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg074.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg077.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg085.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg092.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg106.tif
#   inflating: PhC-C2DH-U373/02_GT/SEG/man_seg112.tif
#    creating: PhC-C2DH-U373/02_GT/TRA/
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track.txt
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track000.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track001.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track002.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track003.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track004.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track005.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track006.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track007.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track008.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track009.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track010.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track011.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track012.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track013.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track014.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track015.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track016.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track017.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track018.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track019.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track020.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track021.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track022.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track023.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track024.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track025.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track026.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track027.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track028.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track029.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track030.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track031.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track032.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track033.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track034.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track035.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track036.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track037.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track038.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track039.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track040.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track041.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track042.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track043.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track044.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track045.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track046.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track047.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track048.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track049.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track050.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track051.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track052.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track053.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track054.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track055.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track056.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track057.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track058.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track059.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track060.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track061.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track062.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track063.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track064.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track065.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track066.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track067.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track068.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track069.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track070.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track071.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track072.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track073.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track074.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track075.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track076.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track077.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track078.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track079.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track080.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track081.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track082.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track083.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track084.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track085.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track086.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track087.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track088.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track089.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track090.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track091.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track092.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track093.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track094.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track095.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track096.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track097.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track098.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track099.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track100.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track101.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track102.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track103.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track104.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track105.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track106.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track107.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track108.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track109.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track110.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track111.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track112.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track113.tif
#   inflating: PhC-C2DH-U373/02_GT/TRA/man_track114.tif
#    creating: PhC-C2DH-U373/02_ST/
#    creating: PhC-C2DH-U373/02_ST/SEG/
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg000.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg001.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg002.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg003.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg004.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg005.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg006.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg007.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg008.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg009.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg010.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg011.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg012.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg013.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg014.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg015.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg016.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg017.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg018.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg019.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg020.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg021.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg022.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg023.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg024.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg025.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg026.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg027.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg028.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg029.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg030.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg031.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg032.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg033.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg034.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg035.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg036.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg037.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg038.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg039.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg040.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg041.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg042.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg043.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg044.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg045.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg046.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg047.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg048.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg049.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg050.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg051.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg052.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg053.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg054.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg055.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg056.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg057.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg058.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg059.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg060.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg061.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg062.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg063.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg064.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg065.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg066.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg067.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg068.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg069.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg070.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg071.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg072.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg073.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg074.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg075.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg076.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg077.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg078.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg079.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg080.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg081.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg082.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg083.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg084.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg085.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg086.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg087.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg088.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg089.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg090.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg091.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg092.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg093.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg094.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg095.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg096.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg097.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg098.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg099.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg100.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg101.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg102.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg103.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg104.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg105.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg106.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg107.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg108.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg109.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg110.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg111.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg112.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg113.tif
#   inflating: PhC-C2DH-U373/02_ST/SEG/man_seg114.tif

# %%
# IMPORTO LIBRERÍAS NECESARIAS
from matplotlib import pyplot as plt
import numpy as np
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import metrics
from tensorflow.keras import backend as K

# %%
from PIL import Image

# %% [markdown]
# # Cargo Train y Val
#
# Train será aumentado

# %%
# EXTRAIGO RECURSOS DEL .ZIP
train_path = Path("PhC-C2DH-U373/01/").glob("**/*tif")
val_path = Path("PhC-C2DH-U373/02/").glob("**/*tif")

# %%
train_images = list()
train_masks = list()
for file in train_path:
    train_images.append(np.array(Image.open(file)).reshape(1,520,696))
    train_masks.append(np.array(Image.open(f'PhC-C2DH-U373/01_ST/SEG/man_seg{file.name[1:]}')).reshape(1,520,696))

val_images = list()
val_masks = list()

for file in val_path:
    val_images.append(np.array(Image.open(file)).reshape(1,520,696))
    val_masks.append(np.array(Image.open(f'PhC-C2DH-U373/02_ST/SEG/man_seg{file.name[1:]}')).reshape(1,520,696))

# %%
train_images = np.vstack(train_images)/255
train_masks = 1*(np.vstack(train_masks) > 0)
val_images = np.vstack(val_images)/255
val_masks = 1*(np.vstack(val_masks) >0 )

# %% [markdown]
# # Imágenes de train sin aumentar

# %% [markdown]
# Imágenes sin utilizar data augmentation: Imprimo el elemento 100

# %%
idx = 100
plt.imshow(train_images[idx], vmin=0, vmax=1, cmap="gray")
plt.imshow(train_masks[idx], vmin=0, vmax=1, cmap="gray",alpha=0.6)
plt.show()

# %% [markdown]
# # Armo datasets de tensorflow y aumento
#
# Para mantener sincronizada la aumentación entre la imagen y la máscara, armo una entrada de 4 canales que de descompondrán durante el entrenamiento.

# %%
x_train = np.stack((train_images, train_masks ),axis=-1)
x_val = np.stack((val_images, val_masks ),axis=-1)

# %%
x_train[0,:,:,0].max()
# Out:
# 0.7254901960784313

# %%
len(x_train)
# Out:
# 115

# %%
plt.imshow(x_train[0,:,:,0], cmap="gray")
plt.imshow(x_train[0,:,:,1], cmap="gray", alpha = 0.5)

# %%
from tensorflow.keras.models import Sequential

# %% [markdown]
# # Armo una red mínima fully convolutional con Atrous Convolutions

# %%
filters = 16
kernel_size = 10
def get_red_seg():
    return Sequential([
        tf.keras.layers.Conv2D(filters, kernel_size,padding="same", activation = "relu", dilation_rate = 1, input_shape = (None,None,1)),
        tf.keras.layers.Conv2D(filters, kernel_size,padding="same", activation = "relu", dilation_rate = 2),
        tf.keras.layers.Conv2D(filters, kernel_size,padding="same", activation = "relu", dilation_rate = 4),
        tf.keras.layers.Conv2D(filters, kernel_size,padding="same", activation = "relu", dilation_rate = 8),
        tf.keras.layers.Conv2D(filters, kernel_size,padding="same", activation = "relu", dilation_rate = 1),
        tf.keras.layers.Conv2D(1, kernel_size,padding="same", activation = "sigmoid", dilation_rate = 1)
    ])

# %% [markdown]
# # Armo la red de preprocesamiento para hacer aumentación en la GPU que no tengo

# %% [markdown]
# Se propone esta red para aumentar el campo de recepción. De esta manera, se prestará más atención a los razgos generales y no tanto a los detalles más finos de la imágen.
#
# ![1_SVkgHoFoiMZkjy54zM_SUw.gif](data:image/gif;base64,...)

# %%
def get_preproc():
    return Sequential([
        tf.keras.layers.RandomCrop(512,512),
        tf.keras.layers.RandomFlip(mode='horizontal_and_vertical'),
        #tf.keras.layers.RandomZoom((-0.1,0.3)),
        #tf.keras.layers.RandomTranslation((-0.5, 0.5), (-0.5,0.5)),
        #tf.keras.layers.RandomRotation((0,1)),
        #tf.keras.layers.RandomZoom((0.5,0.5)),
        ])

def get_preproc_val():
    return Sequential([
        tf.keras.layers.CenterCrop(512,512),
        ])

# %%
preproc = get_preproc()
aux_elem = preproc(x_train[0])
plt.imshow(aux_elem[:,:,0], cmap="gray")
plt.imshow(aux_elem[:,:,1], cmap="gray", alpha = 0.5)

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
class SegmentationModel(Model):
    def __init__(self, red_preproc, red_segmentacion, red_preproc_val):
        super().__init__()
        self.red_segmentacion = red_segmentacion
        self.red_preproc = red_preproc
        self.red_preproc_val = red_preproc_val
        self.loss_tracker = metrics.Mean(name="loss")
        self.dice = False


    def call(self, inputs):
        #img_mask = self.red_preproc = red_preproc(inputs)
        return self.red_segmentacion(inputs[:,:,:1])

    def train_step(self, data):
        # GradientTape is a context manager that records every operation that
        # you do inside. We are using it here to compute the loss so we can get
        # the gradients and apply them using the optimizer specified in
        # `compile()`.
        with tf.GradientTape() as tape:
            data_aug = self.red_preproc(data)
            loss = self._compute_loss(data_aug)
            #print(K.mean(loss))

        # Storing the gradients of the loss function with respect to the
        # weights/parameters.
        gradients = tape.gradient(loss, self.red_segmentacion.trainable_weights)

        # Applying the gradients on the model using the specified optimizer
        self.optimizer.apply_gradients(
            zip(gradients, self.red_segmentacion.trainable_weights)
        )

        # Let's update and return the training loss metric.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        data_preproc = self.red_preproc_val(data)
        loss = self._compute_loss(data_preproc)
        # Let's update and return the loss metric.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def _compute_loss(self, data):
        #aux = self.red_preproc(data)
        mask_out = self.red_segmentacion(data[:,:,:,:1])
        #print(mask_out.shape)
        #print(data[:,:,:,1:2].numpy())
        if self.dice == True:
            loss = dice_loss(data[:,:,:,1:2], mask_out)
        else:
            loss = tf.keras.losses.binary_crossentropy(data[:,:,:,1:2], mask_out)
        return loss

    # property
    # def metrics(self):
    #     # We need to list our metrics here so the `reset_states()` can be
    #     # called automatically.
    #     return [self.loss_tracker]

# %%
red_falopa = get_red_seg()

# %%
red_falopa.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, None, None, 16)    1616
#
#  conv2d_1 (Conv2D)           (None, None, None, 16)    25616
#
#  conv2d_2 (Conv2D)           (None, None, None, 16)    25616
#
#  conv2d_3 (Conv2D)           (None, None, None, 16)    25616
#
#  conv2d_4 (Conv2D)           (None, None, None, 16)    25616
#
#  conv2d_5 (Conv2D)           (None, None, None, 1)     1601
#
# =================================================================
# Total params: 105,681
# Trainable params: 105,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
preproc= get_preproc()
preproc_val = get_preproc_val()
red_falopa = get_red_seg()
model = SegmentationModel(preproc, red_falopa,preproc_val)

# %%
model.compile(optimizer= tf.keras.optimizers.Adam(1e-4))

# %%
len(x_val)
# Out:
# 115

# %% [markdown]
# Entrenamiento de la red

# %%
model.fit(np.vstack([x_train, x_val]),batch_size=16, epochs=45, validation_split = 0.5, verbose = 1)
# Out:
# Epoch 1/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3391 - val_loss: 0.1834
# Epoch 2/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3426 - val_loss: 0.2133
# Epoch 3/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3284 - val_loss: 0.1921
# Epoch 4/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3298 - val_loss: 0.1964
# Epoch 5/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3255 - val_loss: 0.1921
# Epoch 6/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3178 - val_loss: 0.1873
# Epoch 7/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3173 - val_loss: 0.1862
# Epoch 8/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3109 - val_loss: 0.1810
# Epoch 9/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.3050 - val_loss: 0.1793
# Epoch 10/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.2925 - val_loss: 0.1652
# Epoch 11/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.2756 - val_loss: 0.1527
# Epoch 12/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.2447 - val_loss: 0.1482
# Epoch 13/45
# 8/8 [==============================] - 8s 1s/step - loss: 0.1994 - val_loss: 0.0887
# Epoch 14/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.1718 - val_loss: 0.0741
# Epoch 15/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.1479 - val_loss: 0.0824
# Epoch 16/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.1334 - val_loss: 0.0587
# Epoch 17/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.1145 - val_loss: 0.0541
# Epoch 18/45
# 8/8 [==============================] - 10s 1s/step - loss: 0.1082 - val_loss: 0.0542
# Epoch 19/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.1038 - val_loss: 0.0482
# Epoch 20/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.1038 - val_loss: 0.0496
# Epoch 21/45
# 8/8 [==============================] - 10s 1s/step - loss: 0.0926 - val_loss: 0.0476
# Epoch 22/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0967 - val_loss: 0.1073
# Epoch 23/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.1452 - val_loss: 0.0531
# Epoch 24/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.1062 - val_loss: 0.0589
# Epoch 25/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0974 - val_loss: 0.0562
# Epoch 26/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0948 - val_loss: 0.0476
# Epoch 27/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0859 - val_loss: 0.0429
# Epoch 28/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0844 - val_loss: 0.0422
# Epoch 29/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0789 - val_loss: 0.0416
# Epoch 30/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0780 - val_loss: 0.0411
# Epoch 31/45
# 8/8 [==============================] - 10s 1s/step - loss: 0.0755 - val_loss: 0.0407
# Epoch 32/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0788 - val_loss: 0.0483
# Epoch 33/45
# 8/8 [==============================] - 10s 1s/step - loss: 0.0827 - val_loss: 0.0455
# Epoch 34/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0816 - val_loss: 0.0421
# Epoch 35/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0830 - val_loss: 0.0401
# Epoch 36/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0743 - val_loss: 0.0401
# Epoch 37/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0756 - val_loss: 0.0407
# Epoch 38/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0757 - val_loss: 0.0413
# Epoch 39/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0716 - val_loss: 0.0421
# Epoch 40/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0752 - val_loss: 0.0389
# Epoch 41/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0681 - val_loss: 0.0397
# Epoch 42/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0715 - val_loss: 0.0388
# Epoch 43/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0712 - val_loss: 0.0440
# Epoch 44/45
# 8/8 [==============================] - 10s 1s/step - loss: 0.0715 - val_loss: 0.0400
# Epoch 45/45
# 8/8 [==============================] - 9s 1s/step - loss: 0.0671 - val_loss: 0.0383

# %%
pred = red_falopa(x_val[0:1,:,:,0])
pred.shape
# Out:
# TensorShape([1, 520, 696, 1])

# %%
pred.numpy().max()
# Out:
# 0.9820582

# %% [markdown]
# Se muestran los resultados del modelo fully convolutional: se ve que detecta correctamente las zonas de la imagen en las cuales hay bacterias con un margen de error pequeño.

# %%
plt.imshow(x_val[0,:,:,0], cmap="gray")
plt.show()
plt.imshow(x_val[0,:,:,1], cmap="gray", alpha=0.5)
plt.imshow(pred[0,:,:,0]>0.5, cmap="gray", alpha=0.5)
plt.show()

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Concatenate, MaxPooling2D, UpSampling2D,Conv2DTranspose

# %% [markdown]
# La siguiente red a entrenar es la U-NET. Esta estructura se compone de una parte de codificador que captura y extrae características relevantes de la imagen de entrada, y una parte de decodificador que utiliza las características capturadas para generar una salida que tiene la misma forma que la imagen de entrada, pero con una máscara de segmentación asignada a cada píxel.
#
#
# ![unet.png](data:image/png;base64,...)

# %%
img_shape = (512, 512, 1)
def conv_block(m, dim, acti, bn, res, do=0):
	n = Conv2D(dim, 3, activation=acti, padding='same')(m)
	n = BatchNormalization()(n) if bn else n
	n = Dropout(do)(n) if do else n
	n = Conv2D(dim, 3, activation=acti, padding='same')(n)
	n = BatchNormalization()(n) if bn else n
	return Concatenate()([m, n]) if res else n

def level_block(m, dim, depth, inc, acti, do, bn, mp, up, res):
	if depth > 0:
		n = conv_block(m, dim, acti, bn, res)
		m = MaxPooling2D()(n) if mp else Conv2D(dim, 3, strides=2, padding='same')(n)
		m = level_block(m, int(inc*dim), depth-1, inc, acti, do, bn, mp, up, res)
		if up:
			m = UpSampling2D()(m)
			m = Conv2D(dim, 2, activation=acti, padding='same')(m)
		else:
			m = Conv2DTranspose(dim, 3, strides=2, activation=acti, padding='same')(m)
		n = Concatenate()([n, m])
		m = conv_block(n, dim, acti, bn, res)
	else:
		m = conv_block(m, dim, acti, bn, res, do)
	return m

def UNet(img_shape, out_ch=1, start_ch=64, depth=4, inc_rate=2., activation='relu',
		 dropout=0.5, batchnorm=False, maxpool=True, upconv=True, residual=False):
	i = Input(shape=img_shape)
	o = level_block(i, start_ch, depth, inc_rate, activation, dropout, batchnorm, maxpool, upconv, residual)
	o = Conv2D(out_ch, 1, activation='sigmoid')(o)
	return Model(inputs=i, outputs=o)

# %%
preproc_unet= get_preproc()
preproc_unet_val= get_preproc_val()
red_unet = UNet(
    img_shape,
    start_ch = 16,
    dropout = False,
    residual = True
)
model_unet = SegmentationModel(preproc_unet, red_unet,preproc_unet_val)

# %%
model_unet.compile(optimizer= tf.keras.optimizers.Adam(1e-4))

# %%
model_unet.fit(np.vstack([x_train, x_val]),batch_size=16, epochs=45, validation_split = 0.5, verbose = 1)
# Out:
# Epoch 1/45
# 8/8 [==============================] - 11s 1s/step - loss: 0.5071 - val_loss: 0.2900
# Epoch 2/45
# 8/8 [==============================] - 11s 1s/step - loss: 0.3748 - val_loss: 0.2100
# Epoch 3/45
# 8/8 [==============================] - 11s 1s/step - loss: 0.3572 - val_loss: 0.2408
# Epoch 4/45
# 8/8 [==============================] - 11s 1s/step - loss: 0.3461 - val_loss: 0.1992
# Epoch 5/45
# 8/8 [==============================] - 11s 1s/step - loss: 0.3496 - val_loss: 0.2223
# Epoch 6/45
# 8/8 [==============================] - 11s 1s/step - loss: 0.3391 - val_loss: 0.1963
# Epoch 7/45
# 8/8 [==============================] - 12s 1s/step - loss: 0.3350 - val_loss: 0.2049
# Epoch 8/45
# 8/8 [==============================] - 12s 1s/step - loss: 0.3154 - val_loss: 0.1975
# Epoch 9/45
# 8/8 [==============================] - 12s 1s/step - loss: 0.2899 - val_loss: 0.1278
# Epoch 10/45
# 8/8 [==============================] - 12s 1s/step - loss: 0.2374 - val_loss: 0.1187
# Epoch 11/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.2238 - val_loss: 0.0812
# Epoch 12/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1602 - val_loss: 0.0879
# Epoch 13/45
# 8/8 [==============================] - 14s 2s/step - loss: 0.1518 - val_loss: 0.0730
# Epoch 14/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1382 - val_loss: 0.0621
# Epoch 15/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1187 - val_loss: 0.0614
# Epoch 16/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1141 - val_loss: 0.0582
# Epoch 17/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1113 - val_loss: 0.0569
# Epoch 18/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1028 - val_loss: 0.0555
# Epoch 19/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0992 - val_loss: 0.0531
# Epoch 20/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0903 - val_loss: 0.0475
# Epoch 21/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0839 - val_loss: 0.0834
# Epoch 22/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1297 - val_loss: 0.0965
# Epoch 23/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1085 - val_loss: 0.0890
# Epoch 24/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.1009 - val_loss: 0.0756
# Epoch 25/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0916 - val_loss: 0.0621
# Epoch 26/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0852 - val_loss: 0.0590
# Epoch 27/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0756 - val_loss: 0.0460
# Epoch 28/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0692 - val_loss: 0.0397
# Epoch 29/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0629 - val_loss: 0.0382
# Epoch 30/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0598 - val_loss: 0.0381
# Epoch 31/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0560 - val_loss: 0.0368
# Epoch 32/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0552 - val_loss: 0.0422
# Epoch 33/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0567 - val_loss: 0.0346
# Epoch 34/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0542 - val_loss: 0.0401
# Epoch 35/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0507 - val_loss: 0.0456
# Epoch 36/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0590 - val_loss: 0.0408
# Epoch 37/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0529 - val_loss: 0.0344
# Epoch 38/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0507 - val_loss: 0.0516
# Epoch 39/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0558 - val_loss: 0.0393
# Epoch 40/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0583 - val_loss: 0.0526
# Epoch 41/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0571 - val_loss: 0.0321
# Epoch 42/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0489 - val_loss: 0.0319
# Epoch 43/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0453 - val_loss: 0.0362
# Epoch 44/45
# 8/8 [==============================] - 12s 2s/step - loss: 0.0446 - val_loss: 0.0310
# Epoch 45/45
# 8/8 [==============================] - 15s 2s/step - loss: 0.0432 - val_loss: 0.0314

# %%
red_unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_12 (Conv2D)             (None, 512, 512, 16  160         ['input_1[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 512, 512, 16  2320        ['conv2d_12[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 512, 512, 17  0           ['input_1[0][0]',
#                                 )                                 'conv2d_13[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 17  0           ['concatenate[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 32  4928        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 49  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 49  0          ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 64  28288       ['max_pooling2d_1[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_16[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 11  0           ['max_pooling2d_1[0][0]',
#                                 3)                                'conv2d_17[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 113)  0          ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 128)  130304      ['max_pooling2d_2[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_18[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 241)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 241)  0          ['concatenate_3[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 256)  555520      ['max_pooling2d_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_20[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 497)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 497)  0           ['concatenate_4[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 128)  254592      ['up_sampling2d[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 369)  0           ['concatenate_3[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 128)  425216      ['concatenate_5[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_23[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 497)  0           ['concatenate_5[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 49  0          ['concatenate_6[0][0]']
#                                 7)
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 64  127296      ['up_sampling2d_1[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 17  0           ['concatenate_2[0][0]',
#                                 7)                                'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 64  102016      ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_26[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 24  0           ['concatenate_7[0][0]',
#                                 1)                                'conv2d_27[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 24  0          ['concatenate_8[0][0]']
#                                 1)
#
#  conv2d_28 (Conv2D)             (None, 256, 256, 32  30880       ['up_sampling2d_2[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 256, 256, 81  0           ['concatenate_1[0][0]',
#                                 )                                 'conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 32  23360       ['concatenate_9[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_29[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 256, 256, 11  0           ['concatenate_9[0][0]',
#                                 3)                                'conv2d_30[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 512, 512, 11  0          ['concatenate_10[0][0]']
#                                 3)
#
#  conv2d_31 (Conv2D)             (None, 512, 512, 16  7248        ['up_sampling2d_3[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 512, 512, 33  0           ['concatenate[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 512, 512, 16  4768        ['concatenate_11[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 512, 512, 16  2320        ['conv2d_32[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 512, 512, 49  0           ['concatenate_11[0][0]',
#                                 )                                 'conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 512, 512, 1)  50          ['concatenate_12[0][0]']
#
# ==================================================================================================
# Total params: 2,676,866
# Trainable params: 2,676,866
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
aux = preproc_unet_val(x_val[0:1,:,:,:])
pred = red_unet(aux[0:1,:,:,0])
pred.shape
# Out:
# TensorShape([1, 512, 512, 1])

# %%
pred.numpy().max()
# Out:
# 0.9964324

# %% [markdown]
# Se muestran los resultados de la red U-NET: se clasifican los píxeles de la imagen original. La imagen que devuelve el modelo corresponde a esta selección. Se pude ver que identifica correctamente las regiones en las que hay bacterias.

# %%
plt.imshow(aux[0,:,:,0], cmap="gray")
plt.show()
plt.imshow(aux[0,:,:,1], cmap="gray", alpha = 0.5)
plt.show()
plt.imshow(pred[0,:,:,0]>0.7, cmap="gray", alpha = 0.5)
plt.show()
